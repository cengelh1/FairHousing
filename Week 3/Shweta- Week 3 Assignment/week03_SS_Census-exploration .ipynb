# %% [markdown]
# ## Exploring number of housing units across census tracts in Los Angeles City
# By Shweta Sundar

# %%
# analysing the distribution of the number of housing units per census tract in the city of Los Angeles
# importing libraries and data 
import pandas as pd

# %%
#importing data into the notebook after downloading from Social Explorer
df = pd.read_csv('R13285219_SL140 (1).csv')

# %%
#inspecting the data file
df.shape
df.head()
# Out:
#      Geo_FIPS                                          Geo_QName Geo_FILEID  \
# 0  6037101110  Census Tract 1011.10, Los Angeles County, Cali...      ACSSF
# 1  6037101122  Census Tract 1011.22, Los Angeles County, Cali...      ACSSF
# 2  6037101220  Census Tract 1012.20, Los Angeles County, Cali...      ACSSF
# 3  6037101221  Census Tract 1012.21, Los Angeles County, Cali...      ACSSF
# 4  6037101222  Census Tract 1012.22, Los Angeles County, Cali...      ACSSF
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO  Geo_US  Geo_REGION  \
# 0         ca         140            0          4200     NaN         NaN
# 1         ca         140            0          4201     NaN         NaN
# 2         ca         140            0          4202     NaN         NaN
# 3         ca         140            0          4203     NaN         NaN
# 4         ca         140            0          4204     NaN         NaN
#
#    Geo_DIVISION  ...  Geo_TAZ  Geo_UGA  Geo_PUMA5  Geo_PUMA1  \
# ...

# %%
# I want to see all the data
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.sample()
# Out:
#        Geo_FIPS                                          Geo_QName Geo_FILEID  \
# 245  6037127711  Census Tract 1277.11, Los Angeles County, Cali...      ACSSF
#
#     Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO  Geo_US  Geo_REGION  \
# 245         ca         140            0          4445     NaN         NaN
#
#      Geo_DIVISION  Geo_STATECE  Geo_STATE  Geo_COUNTY  Geo_COUSUB  Geo_PLACE  \
# 245           NaN          NaN          6          37         NaN        NaN
#
#      Geo_TRACT  Geo_BLKGRP  Geo_CONCIT  Geo_AIANHH  Geo_AIANHHFP  Geo_AIHHTLI  \
# 245     127711         NaN         NaN         NaN           NaN          NaN
#
#      Geo_AITSCE  Geo_AITS  Geo_ANRC  Geo_CBSA  Geo_CSA  Geo_METDIV  Geo_MACC  \
# 245         NaN       NaN       NaN       NaN      NaN         NaN       NaN
#
#      Geo_MEMI  Geo_NECTA  Geo_CNECTA  Geo_NECTADIV  Geo_UA  Geo_UACP  \
# 245       NaN        NaN         NaN           NaN     NaN       NaN
#
# ...

# %%
# look at the data types
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2498 entries, 0 to 2497
# Data columns (total 56 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geo_FIPS       2498 non-null   int64
#  1   Geo_QName      2498 non-null   object
#  2   Geo_FILEID     2498 non-null   object
#  3   Geo_STUSAB     2498 non-null   object
#  4   Geo_SUMLEV     2498 non-null   int64
#  5   Geo_GEOCOMP    2498 non-null   int64
#  6   Geo_LOGRECNO   2498 non-null   int64
#  7   Geo_US         0 non-null      float64
#  8   Geo_REGION     0 non-null      float64
#  9   Geo_DIVISION   0 non-null      float64
#  10  Geo_STATECE    0 non-null      float64
#  11  Geo_STATE      2498 non-null   int64
#  12  Geo_COUNTY     2498 non-null   int64
#  13  Geo_COUSUB     0 non-null      float64
#  14  Geo_PLACE      0 non-null      float64
#  15  Geo_TRACT      2498 non-null   int64
#  16  Geo_BLKGRP     0 non-null      float64
# ...

# %%
# looking closely at the unique identifier for each census tract Geo_FIPS
df.Geo_FIPS.head()
# Out:
# 0    6037101110
# 1    6037101122
# 2    6037101220
# 3    6037101221
# 4    6037101222
# Name: Geo_FIPS, dtype: int64

# %%
# seeing the geodata for state
df.Geo_STATE.head()
# Out:
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6
# Name: Geo_STATE, dtype: int64

# %%
# seeing the geodata for county
df.Geo_COUNTY.head()
# Out:
# 0    37
# 1    37
# 2    37
# 3    37
# 4    37
# Name: Geo_COUNTY, dtype: int64

# %%
# changing the type of data for the aforementioned datasets to get the correct Geo_FIPS code
df= pd.read_csv(
    'R13285219_SL140 (1).csv',
    dtype= 
    {'Geo_FIPS': str,
     'Geo_STATE': str,
     'Geo_COUNTY': str})

# %%
df.head()
# Out:
#       Geo_FIPS                                          Geo_QName Geo_FILEID  \
# 0  06037101110  Census Tract 1011.10, Los Angeles County, Cali...      ACSSF
# 1  06037101122  Census Tract 1011.22, Los Angeles County, Cali...      ACSSF
# 2  06037101220  Census Tract 1012.20, Los Angeles County, Cali...      ACSSF
# 3  06037101221  Census Tract 1012.21, Los Angeles County, Cali...      ACSSF
# 4  06037101222  Census Tract 1012.22, Los Angeles County, Cali...      ACSSF
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO  Geo_US  Geo_REGION  \
# 0         ca         140            0          4200     NaN         NaN
# 1         ca         140            0          4201     NaN         NaN
# 2         ca         140            0          4202     NaN         NaN
# 3         ca         140            0          4203     NaN         NaN
# 4         ca         140            0          4204     NaN         NaN
#
# ...

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2498 entries, 0 to 2497
# Data columns (total 56 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geo_FIPS       2498 non-null   object
#  1   Geo_QName      2498 non-null   object
#  2   Geo_FILEID     2498 non-null   object
#  3   Geo_STUSAB     2498 non-null   object
#  4   Geo_SUMLEV     2498 non-null   int64
#  5   Geo_GEOCOMP    2498 non-null   int64
#  6   Geo_LOGRECNO   2498 non-null   int64
#  7   Geo_US         0 non-null      float64
#  8   Geo_REGION     0 non-null      float64
#  9   Geo_DIVISION   0 non-null      float64
#  10  Geo_STATECE    0 non-null      float64
#  11  Geo_STATE      2498 non-null   object
#  12  Geo_COUNTY     2498 non-null   object
#  13  Geo_COUSUB     0 non-null      float64
#  14  Geo_PLACE      0 non-null      float64
#  15  Geo_TRACT      2498 non-null   int64
#  16  Geo_BLKGRP     0 non-null      float64
# ...

# %%
# seeing which columns have a zero value
df.columns[df.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_STATECE',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_BLKGRP',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITSCE',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_CNECTA',
#  'Geo_NECTADIV',
#  'Geo_UA',
#  'Geo_UACP',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_VTD',
#  'Geo_ZCTA3',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_TAZ',
#  'Geo_UGA',
#  'Geo_PUMA5',
#  'Geo_PUMA1',
#  'Geo_BTTR',
#  'Geo_BTBG',
#  'Geo_PLACESE']

# %%
# drop all columns with 0 values
df = df.dropna(axis=1,how='all')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2498 entries, 0 to 2497
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geo_FIPS       2498 non-null   object
#  1   Geo_QName      2498 non-null   object
#  2   Geo_FILEID     2498 non-null   object
#  3   Geo_STUSAB     2498 non-null   object
#  4   Geo_SUMLEV     2498 non-null   int64
#  5   Geo_GEOCOMP    2498 non-null   int64
#  6   Geo_LOGRECNO   2498 non-null   int64
#  7   Geo_STATE      2498 non-null   object
#  8   Geo_COUNTY     2498 non-null   object
#  9   Geo_TRACT      2498 non-null   int64
#  10  Geo_GEOID      2498 non-null   object
#  11  Geo_NAME       2498 non-null   object
#  12  SE_A10001_001  2498 non-null   int64
# dtypes: int64(5), object(8)
# memory usage: 253.8+ KB

# %%
# defining columns to keep 
columns_needed = ['Geo_FIPS',
                  'SE_A10001_001']

# creating a new datadrame with columns_needed
df2 = df[columns_needed]

# %%
df2.head()
# Out:
#       Geo_FIPS  SE_A10001_001
# 0  06037101110           1639
# 1  06037101122           1426
# 2  06037101220           1399
# 3  06037101221           1556
# 4  06037101222            994

# %%
# renaming columns
df2.columns.to_list()
# Out:
# ['Geo_FIPS', 'SE_A10001_001']

# %%
df2.columns = ['FIPS', 'No_Housing_Units']

# %%
df2.columns.to_list()
# Out:
# ['FIPS', 'No_Housing_Units']

# %%
df2.shape
# Out:
# (2498, 2)

# %%
# what is the mean of the number of housing units per census tract in Los Angeles
df2['No_Housing_Units'].mean()
# Out:
# 1432.6665332265814

# %%
# what is the median of the number of housing units per census tract in Los Angeles
df2['No_Housing_Units'].median()
# Out:
# 1363.5

# %%
df2['No_Housing_Units'].describe()
# Out:
# count    2498.000000
# mean     1432.666533
# std       599.300827
# min         0.000000
# 25%      1041.000000
# 50%      1363.500000
# 75%      1743.750000
# max      6307.000000
# Name: No_Housing_Units, dtype: float64

# %%
# to visually understand between what numbers do the bulk of the housing units per census tracts fall using a histogram
df2['No_Housing_Units'].plot.hist(bins=100)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
#  visualising the same using a box plot
df2.boxplot(column=['No_Housing_Units'])
# Out:
# <AxesSubplot: >

# %%
# I want to know what are the top 10 census tracts with the most number of housing units
df_sorted = df2.sort_values(by= 'No_Housing_Units', ascending = False)
df_sorted[['FIPS','No_Housing_Units']].head(10)
# Out:
#              FIPS  No_Housing_Units
# 2278  06037702900              6307
# 1028  06037275604              4964
# 2239  06037700200              4635
# 606   06037207902              4593
# 2255  06037701402              4476
# 472   06037191000              4387
# 2240  06037700300              4330
# 2266  06037702102              4315
# 2025  06037576001              4283
# 2046  06037577300              3910

# %%
# I want to know what ate the bottom 50 census tracts with the least number of housing units
df_sorted_low = df2.sort_values(by= 'No_Housing_Units', ascending = True)
df_sorted_low[['FIPS','No_Housing_Units']].head(50)
# Out:
#              FIPS  No_Housing_Units
# 2497  06037990300                 0
# 2462  06037980004                 0
# 2463  06037980005                 0
# 2464  06037980006                 0
# 2465  06037980007                 0
# 2467  06037980009                 0
# 2470  06037980012                 0
# 2471  06037980013                 0
# 2494  06037980039                 0
# 2493  06037980038                 0
# 2492  06037980037                 0
# 938   06037265301                 0
# 2058  06037578100                 0
# 2476  06037980018                 0
# 2478  06037980020                 0
# 2480  06037980022                 0
# 2481  06037980023                 0
# 2484  06037980026                 0
# 2496  06037990200                 0
# 2485  06037980028                 0
# 2461  06037980003                 0
# 2460  06037980002                 0
# 2486  06037980030                 0
# 2334  06037901003                 0
# 2495  06037990100                 0
# ...

# %%
# plotting the top 10 census tracts with the most number of housing units
df_sorted.head(10).plot.bar(x= 'FIPS',
                            y= 'No_Housing_Units')
# Out:
# <AxesSubplot: xlabel='FIPS'>

# %%
df_sorted.head(10).plot.barh(x= 'FIPS',
                            y= 'No_Housing_Units',
                           title = 'Top 10 Census Tracts with Highest Population in Los Angeles COunty in 2020',
                           color = 'purple')
# Out:
# <AxesSubplot: title={'center': 'Top 10 Census Tracts with Highest Population in Los Angeles COunty in 2020'}, ylabel='FIPS'>

# %%
# importing geopandas to plot map
import geopandas as gpd

# %%
# importing a LA county census tract geojson file from the class data
tracts = gpd.read_file('Census_Tracts_2020.geojson')
tracts.head()
# Out:
#    OBJECTID    CT20    LABEL   ShapeSTArea  ShapeSTLength  \
# 0         1  101110  1011.10  1.229562e+07   15083.854287
# 1         2  101122  1011.22  2.845774e+07   31671.455844
# 2         3  101220  1012.20  7.522093e+06   12698.783810
# 3         4  101221  1012.21  3.812000e+06    9161.710543
# 4         5  101222  1012.22  3.191371e+06    9980.600461
#
#                                             geometry
# 0  POLYGON ((-118.28491 34.25948, -118.28492 34.2...
# 1  POLYGON ((-118.29015 34.27417, -118.29015 34.2...
# 2  POLYGON ((-118.28100 34.25592, -118.28198 34.2...
# 3  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  POLYGON ((-118.28594 34.25405, -118.28594 34.2...

# %%
# plotting geojson file
tracts.plot(figsize = (12,10))
# Out:
# <AxesSubplot: >

# %%
# what type of data in this dataset 
tracts.info(verbose=True, show_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2495 entries, 0 to 2494
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OBJECTID       2495 non-null   int64
#  1   CT20           2495 non-null   object
#  2   LABEL          2495 non-null   object
#  3   ShapeSTArea    2495 non-null   float64
#  4   ShapeSTLength  2495 non-null   float64
#  5   geometry       2495 non-null   geometry
# dtypes: float64(2), geometry(1), int64(1), object(2)
# memory usage: 117.1+ KB

# %%
# extracting only FIPS and geometry data from the data
tracts = tracts [['CT20', 'geometry']]
tracts.head()
# Out:
#      CT20                                           geometry
# 0  101110  POLYGON ((-118.28491 34.25948, -118.28492 34.2...
# 1  101122  POLYGON ((-118.29015 34.27417, -118.29015 34.2...
# 2  101220  POLYGON ((-118.28100 34.25592, -118.28198 34.2...
# 3  101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  101222  POLYGON ((-118.28594 34.25405, -118.28594 34.2...

# %%
#creating a FIPS column to be able to import other data into this dataset
tracts['FIPS'] = '06'+'037'+tracts['CT20']
tracts.head()
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#      CT20                                           geometry         FIPS
# 0  101110  POLYGON ((-118.28491 34.25948, -118.28492 34.2...  06037101110
# 1  101122  POLYGON ((-118.29015 34.27417, -118.29015 34.2...  06037101122
# 2  101220  POLYGON ((-118.28100 34.25592, -118.28198 34.2...  06037101220
# 3  101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...  06037101221
# 4  101222  POLYGON ((-118.28594 34.25405, -118.28594 34.2...  06037101222

# %%
tracts= tracts[['FIPS','geometry']]
tracts.head()
# Out:
#           FIPS                                           geometry
# 0  06037101110  POLYGON ((-118.28491 34.25948, -118.28492 34.2...
# 1  06037101122  POLYGON ((-118.29015 34.27417, -118.29015 34.2...
# 2  06037101220  POLYGON ((-118.28100 34.25592, -118.28198 34.2...
# 3  06037101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  06037101222  POLYGON ((-118.28594 34.25405, -118.28594 34.2...

# %%
#merging the geojson dataset with the dataset with housing units
tracts_housing = tracts.merge(df2, on='FIPS')

# %%
tracts_housing.head()
# Out:
#           FIPS                                           geometry  \
# 0  06037101110  POLYGON ((-118.28491 34.25948, -118.28492 34.2...
# 1  06037101122  POLYGON ((-118.29015 34.27417, -118.29015 34.2...
# 2  06037101220  POLYGON ((-118.28100 34.25592, -118.28198 34.2...
# 3  06037101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  06037101222  POLYGON ((-118.28594 34.25405, -118.28594 34.2...
#
#    No_Housing_Units
# 0              1639
# 1              1426
# 2              1399
# 3              1556
# 4               994

# %%
# plotting column with number of housing units per census tract
tracts_housing.plot(figsize = (12,15),
                     column = 'No_Housing_Units',
                     legend = True, 
                     scheme ='natural_breaks')
# Out:
# <AxesSubplot: >

# %%
# filtering top 10 censts tracts with highest number of houses
tracts_housing_high = tracts_housing.sort_values(by= 'No_Housing_Units', ascending = False)

# %%
tracts_housing_high = tracts_housing_high.iloc[0:10]
tracts_housing_high.shape
# Out:
# (10, 3)

# %%
# plotting top 10 censts tracts with highest number of houses
tracts_housing_high.plot(figsize = (12,10),
                     column = 'No_Housing_Units',
                     legend = True, 
                     scheme ='natural_breaks')
# Out:
# <AxesSubplot: >

# %%
import folium

# %%
m = folium.Map(location=[34.2,-118.2], 
               zoom_start = 9,
               tiles='CartoDB positron', 
               attribution='CartoDB')

# plot chorpleth over the base map
folium.Choropleth(
                  geo_data=tracts_housing, # geo data
                  data=tracts_housing, # data          
                  key_on='feature.properties.FIPS', # key, or merge column
                  columns=['FIPS', 'No_Housing_Units'], # [key, value]
                  fill_color='BuPu',
                  line_weight=0.1, 
                  fill_opacity=0.8,
                  line_opacity=0.2, # line opacity (of the border)
                  legend_name='Distribution of housing units (2020)').add_to(m)    # name on the legend color bar
